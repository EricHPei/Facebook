# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('../train.csv')

# %%
df.describe()
# Out:
#                 row_id                x                y         accuracy  \
# count  29118021.000000  29118021.000000  29118021.000000  29118021.000000
# mean   14559010.000000         4.999770         5.001814        82.849125
# std     8405648.775647         2.857601         2.887505       114.751772
# min           0.000000         0.000000         0.000000         1.000000
# 25%     7279505.000000         2.534700         2.496700        27.000000
# 50%    14559010.000000         5.009100         4.988300        62.000000
# 75%    21838515.000000         7.461400         7.510300        75.000000
# max    29118020.000000        10.000000        10.000000      1033.000000
#
#                   time      place_id
# count  29118021.000000  2.911802e+07
# mean     417010.364723  5.493787e+09
# std      231176.146498  2.611088e+09
# min           1.000000  1.000016e+09
# 25%      203057.000000  3.222911e+09
# 50%      433922.000000  5.518573e+09
# 75%      620491.000000  7.764307e+09
# max      786239.000000  9.999932e+09

# %%
dfsample = df.sample(frac=.04)

# %%
#len(set(df.place_id))
from collections import Counter
df.accuracy.value_counts()
# Out:
# 65      1212970
# 66       623391
# 64       618559
# 67       605218
# 63       601226
# 68       580823
# 62       576806
# 10       561614
# 69       547914
# 61       544468
# 70       511351
# 60       508280
# 71       468111
# 59       467502
# 72       425790
# 58       424346
# 5        416462
# 57       383197
# 73       380866
# 9        353101
# 8        347049
# 11       342834
# 56       341991
# 7        338720
# 74       337588
# 12       334621
# 6        328458
# 13       319881
# 14       304222
# 55       300422
#          ...
# 995         736
# 997         708
# 998         664
# 999         567
# 1000        493
# 1001        446
# 1002        386
# 1003        354
# 1004        294
# 1005        272
# 1006        226
# 1007        166
# 1008        149
# 1009        115
# 1010         93
# 1011         80
# 1012         69
# 1013         60
# 1015         27
# 1014         23
# 1016         22
# 1018         18
# 1017         17
# 1020          7
# 1021          6
# 1022          6
# 1019          5
# 1028          1
# 1029          1
# 1033          1
# Name: accuracy, dtype: int64

# %%
y = df['place_id']

# %%
X = df.iloc[:,:-1]

# %%
df.head()
# Out:
#    row_id       x       y  accuracy    time    place_id
# 0       0  0.7941  9.0809        54  470702  8523065625
# 1       1  5.9567  4.7968        13  186555  1757726713
# 2       2  8.3078  7.0407        74  322648  1137537235
# 3       3  7.3665  2.5165        65  704587  6567393236
# 4       4  4.0961  1.1307        31  472130  7440663949

# %%
df.tail()
# Out:
#             row_id       x       y  accuracy    time    place_id
# 29118016  29118016  6.5133  1.1435        67  399740  8671361106
# 29118017  29118017  5.9186  4.4134        67  125480  9077887898
# 29118018  29118018  2.9993  6.3680        67  737758  2838334300
# 29118019  29118019  4.0637  8.0061        70  764975  1007355847
# 29118020  29118020  7.4523  2.0871        17  102842  7028698129

# %%
X.head()
# Out:
#    row_id       x       y  accuracy    time
# 0       0  0.7941  9.0809        54  470702
# 1       1  5.9567  4.7968        13  186555
# 2       2  8.3078  7.0407        74  322648
# 3       3  7.3665  2.5165        65  704587
# 4       4  4.0961  1.1307        31  472130

# %%
len(df['place_id'].unique())
# Out:
# 108390

# %%
plt.figure(0, figsize=(14,14))
plt.subplot(321)
plt.grid(True)
plt.xlabel('x')
plt.ylabel('frequency')
plt.title('Distribution of X')
plt.hist(df['x'], bins=100)

plt.subplot(322)
plt.grid(True)
plt.xlabel('y')
plt.ylabel('frequency')
plt.title('Distribution of Y')
plt.hist(df['y'], bins=100)

plt.subplot(323)
plt.hist(df['time'], bins=100)
plt.xlabel('time')
plt.ylabel('frequency')
plt.title('Distribution of time')

plt.subplot(324)
plt.hist(df['accuracy'], bins=1000)
plt.xlabel('accuracy')
plt.ylabel('frequency')
plt.xlim(0,200)
plt.title('Distribution of accuracy')

plt.subplot(325)
plt.hist(y, bins=100)
plt.xlabel('accuracy')
plt.ylabel('frequency')
plt.title('Distribution of locations')
plt.show()

# %%
plt.figure(1, figsize=(14,10))

plt.subplot(221)
plt.grid(True)
plt.xlabel('Number of Check Ins')
plt.ylabel('Frequency')
plt.title('Distribution of Check In Frequency')
plt.hist(y.value_counts(), bins=100)

#just checking x and y
plt.subplot(222)
plt.grid(True)
plt.xlabel('Number of Identical X')
plt.ylabel('Frequency')
plt.title('Distribution of X Frequency')
plt.hist(df['x'].value_counts(), bins=100)

plt.subplot(223)
plt.grid(True)
plt.xlabel('Number of Identical Y')
plt.ylabel('Frequency')
plt.title('Distribution of Y Frequency')
plt.hist(df['y'].value_counts(), bins=100)

#what does this mean
plt.subplot(224)
plt.grid(True)
plt.xlabel('Number of Accuracy')
plt.ylabel('Frequency')
plt.title('Distribution of Accuracy Frequency')
plt.hist(df['accuracy'].value_counts(), bins=50)

plt.show()

# %%
df['time'].describe()
# Out:
# count    29118021.000000
# mean       417010.364723
# std        231176.146498
# min             1.000000
# 25%        203057.000000
# 50%        433922.000000
# 75%        620491.000000
# max        786239.000000
# Name: time, dtype: float64

# %%
dfsample.describe()
# Out:
#                 row_id               x               y        accuracy  \
# count   1164721.000000  1164721.000000  1164721.000000  1164721.000000
# mean   14551911.539315        5.002001        5.002971       82.835702
# std     8407011.244809        2.856221        2.886574      114.816215
# min           2.000000        0.000000        0.000000        1.000000
# 25%     7268066.000000        2.538200        2.499000       27.000000
# 50%    14554063.000000        5.016400        4.990200       62.000000
# 75%    21829658.000000        7.463400        7.506700       75.000000
# max    29117995.000000        9.999900       10.000000     1029.000000
#
#                  time      place_id
# count  1164721.000000  1.164721e+06
# mean    417129.777496  5.495849e+09
# std     231114.806409  2.610012e+09
# min          7.000000  1.000016e+09
# 25%     203128.000000  3.226540e+09
# 50%     434554.000000  5.522607e+09
# 75%     620506.000000  7.764787e+09
# max     786239.000000  9.999932e+09

# %%
plt.figure(3, figsize=(14,15))

from matplotlib import cm as CM
from matplotlib import mlab as ML


plt.subplot(321)
x = dfsample['time']
y = dfsample['accuracy'] 
gridsize=50
plt.xlabel('Time')
plt.ylabel('Accuracy')
plt.title('Time vs Accuracy')
plt.hexbin(x, y, gridsize=gridsize, cmap=CM.jet, bins=None)
plt.axis([x.min(), x.max(), y.min(), y.max()])
cb = plt.colorbar()
cb.set_label('mean value')


plt.subplot(322)
x = dfsample['time']
y = dfsample['x'] 
gridsize=50
plt.xlabel('Time')
plt.ylabel('X')
plt.title('Time vs X')
plt.hexbin(x, y, gridsize=gridsize, cmap=CM.jet, bins=None)
plt.axis([x.min(), x.max(), y.min(), y.max()])
cb = plt.colorbar()
cb.set_label('mean value')

plt.subplot(323)
x = dfsample['time']
y = dfsample['y'] 
gridsize=50
plt.xlabel('Time')
plt.ylabel('Y')
plt.title('Time vs Y')
plt.hexbin(x, y, gridsize=gridsize, cmap=CM.jet, bins=None)
plt.axis([x.min(), x.max(), y.min(), y.max()])
cb = plt.colorbar()
cb.set_label('mean value')

plt.subplot(324)
x = dfsample['accuracy']
y = dfsample['x'] 
gridsize=50
plt.xlabel('Accuracy')
plt.ylabel('X')
plt.title('Accuracy vs X')
plt.hexbin(x, y, gridsize=gridsize, cmap=CM.jet, bins=None)
plt.axis([x.min(), x.max(), y.min(), y.max()])
cb = plt.colorbar()
cb.set_label('mean value')

plt.subplot(325)
x = dfsample['accuracy']
y = dfsample['y'] 
gridsize=50
plt.xlabel('Accuracy')
plt.ylabel('Y')
plt.title('Accuracy vs Y')
plt.hexbin(x, y, gridsize=gridsize, cmap=CM.jet, bins=None)
plt.axis([x.min(), x.max(), y.min(), y.max()])
cb = plt.colorbar()
cb.set_label('mean value')

plt.subplot(326)
x = dfsample['x']
y = dfsample['y'] 
gridsize=50
plt.xlabel('X')
plt.ylabel('Y')
plt.title('X vs Y')
plt.hexbin(x, y, gridsize=gridsize, cmap=CM.jet, bins=None)
plt.axis([x.min(), x.max(), y.min(), y.max()])
cb = plt.colorbar()
cb.set_label('mean value')

plt.show()

# %% [markdown]
# ### seems like no interactions

# %%
plt.hist(dfsample['place_id'].value_counts())
plt.show()

# %%
dfsample['place_id'].value_counts()[:10]
# Out:
# 4638096372    89
# 1125237044    85
# 7698408658    83
# 4631665153    83
# 6824036132    82
# 3623653203    80
# 8867637381    80
# 1628743555    80
# 4823777529    79
# 5656490844    79
# Name: place_id, dtype: int64

# %%
top_ten_places = dfsample['place_id'].value_counts()[:10]
for i in top_ten_places:

# %%
dfsample['place_id'].describe()
# Out:
# count    1.164721e+06
# mean     5.495849e+09
# std      2.610012e+09
# min      1.000016e+09
# 25%      3.226540e+09
# 50%      5.522607e+09
# 75%      7.764787e+09
# max      9.999932e+09
# Name: place_id, dtype: float64

# %%
#subset = df[df['place_id'] == 8523065625]
subset = df[df['x']<0.2]
subset2 = subset[subset['y']<0.2]
#subset2 = subset1[subset1['place_id']<1500000000]

# %%
cmap = plt.cm.CMRmap
plt.scatter(subset2.x, subset2.y, c=subset2.place_id, edgecolor='none', alpha=0.9, cmap=cmap)
